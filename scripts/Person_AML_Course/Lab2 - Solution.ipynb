# %% [markdown]
# # Start a Experiment

# %% [markdown]
# # Connect to the Azure ML Workspace

# %%
import azureml.core
from azureml.core import Workspace

ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Performing interactive authentication. Please follow the instructions on the terminal.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code CX8SJVXKB to authenticate.
# Interactive authentication successfully completed.
# Ready to use Azure ML 1.51.0 to work with poc-smuc-paas-we-ml

# %% [markdown]
# ## 2. Start an experiment

# %%
from azureml.core import Experiment
import pandas as pd

experiment = Experiment(workspace=ws, name="pearson-titanic")

run = experiment.start_logging()
print("Starting experiment:", experiment.name)
# Out:
# Starting experiment: pearson-titanic

# %% [markdown]
# ## 3. Read data

# %%
data = pd.read_csv('data/titanic.csv')

# %% [markdown]
# ## 4. Count number of rows and log the metric

# %%
row_count = (len(data))
run.log('row_count', row_count)

# %% [markdown]
# ## 5. End experiment and query metrics

# %%
run.complete()

print("Metrics:")
metrics = run.get_metrics()
for metric_name in metrics:
    print(metric_name, ":", metrics[metric_name])
